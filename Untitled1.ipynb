# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import pandas as pd
from fastai import *
from fastai.vision import *

# %%
bs = 32 # batch size
sz=224 # image size

# %%
base_image = Path('/home/sudarshan/Desktop/finaYearProject/dataset2-master/images')
base_image/'TRAIN'
data = ImageDataBunch.from_folder(path=base_image,train='TRAIN',valid='TEST',size=sz,bs=bs,num_workers=0).normalize(imagenet_stats)

# %%
data.show_batch()

# %%
print(data.classes)
# Out:
# ['EOSINOPHIL', 'LYMPHOCYTE', 'MONOCYTE', 'NEUTROPHIL']

# %%
len(data.classes),data.c
# Out:
# (4, 4)

# %%
model_path=Path('/tmp/models/')

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate,model_dir=model_path)
# Out:
# /home/sudarshan/.local/lib/python3.6/site-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.lr_find()
# Out:
# epoch     train_loss  valid_loss  error_rate  time
# 0         9.535041    #na#        09:01
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# /home/sudarshan/.local/lib/python3.6/site-packages/fastai/sixel.py:16: UserWarning: You could see this plot with `libsixel`. See https://github.com/saitoha/libsixel
#   warn("You could see this plot with `libsixel`. See https://github.com/saitoha/libsixel")

# %%
learn.fit_one_cycle(4,max_lr=1e-2)
# Out:
# epoch     train_loss  valid_loss  error_rate  time
# 0         0.293747    0.998120    0.227181    35:01
# █
